# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
import statsmodels.api as sm

# %%
fd= pd.read_csv("multiple_linear_regression.csv")
fd.head()
# Out:
#    Feature 1  Feature 2  Feature 3  Target
# 0      230.1       37.8       69.2    22.1
# 1       44.5       39.3       45.1    10.4
# 2       17.2       45.9       69.3     9.3
# 3      151.5       41.3       58.5    18.5
# 4      180.8       10.8       58.4    12.9

# %%
x = fd.iloc[ : , fd.columns != "Target"]
y = fd.loc[ : , "Target" ]

# %%
x_train,x_test,y_train,y_test = train_test_split( x,y , train_size = 0.30,random_state = 43)

# %%
x_with_constant = sm.add_constant(x_train)

# %%
x_with_constant.shape
# Out:
# (60, 4)

# %%
model = sm.OLS(y_train,x_with_constant)

# %%
result = model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Target   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     170.4
# Date:                Thu, 20 Jun 2024   Prob (F-statistic):           4.04e-28
# Time:                        11:23:09   Log-Likelihood:                -113.08
# No. Observations:                  60   AIC:                             234.2
# Df Residuals:                      56   BIC:                             242.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0999      0.585      7.012      0.000       2.929       5.271
# ...

# %%
x_with_constant.drop(columns = "Feature 3",inplace = True)

# %%
x_with_constant
# Out:
#      const  Feature 1  Feature 2
# 24     1.0       62.3       12.6
# 70     1.0      199.1       30.6
# 182    1.0       56.2        5.7
# 131    1.0      265.2        2.9
# 23     1.0      228.3       16.9
# 52     1.0      216.4       41.7
# 106    1.0       25.0       11.0
# 193    1.0      166.8       42.0
# 156    1.0       93.9       43.5
# 99     1.0      135.2       41.7
# 163    1.0      163.5       36.8
# 7      1.0      120.2       19.6
# 27     1.0      240.1       16.7
# 74     1.0      213.4       24.6
# 196    1.0       94.2        4.9
# 154    1.0      187.8       21.1
# 118    1.0      125.7       36.9
# 157    1.0      149.8        1.3
# 153    1.0      171.3       39.7
# 3      1.0      151.5       41.3
# 104    1.0      238.2       34.3
# 47     1.0      239.9       41.5
# 84     1.0      213.5       43.0
# 61     1.0      261.3       42.7
# 135    1.0       48.3       47.0
# 170    1.0       50.0       11.6
# 28     1.0      248.8       27.1
# ...

# %%
model2 = sm.OLS(y_train,x_with_constant)

# %%
result2 = model2.fit()

# %%
print(result2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Target   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     251.3
# Date:                Thu, 20 Jun 2024   Prob (F-statistic):           5.33e-29
# Time:                        11:24:29   Log-Likelihood:                -114.01
# No. Observations:                  60   AIC:                             234.0
# Df Residuals:                      57   BIC:                             240.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.7726      0.534      7.069      0.000       2.704       4.841
# ...

# %%
fd.drop(columns = "Feature 3",inplace = True)

# %%
x = fd.iloc[ : , fd.columns != "Target"]
y = fd.loc[ : , "Target" ]
x_train,x_test,y_train,y_test = train_test_split( x,y , train_size = 0.30,random_state = 43)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
residual = y_test - pred

# %%
sns.distplot(residual)
# Out:
# C:\Users\raghu\AppData\Local\Temp\ipykernel_7696\1108040850.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residual)
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Target', ylabel='Density'>

# %%
plt.scatter(pred,residual)
