# %%
import pandas as pd
import seaborn as sns

# %%
fd = pd.read_csv("googleplaystore.csv")

# %%
fd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## 1.Using values analysis columns

# %%
fd1 = fd.values

# %%
fd1.shape
# Out:
# (10841, 13)

# %%
for i in fd1:
    print(i)
    break
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'ART_AND_DESIGN' 4.1
#  '159' '19M' '10,000+' 'Free' '0' 'Everyone' 'Art & Design'
#  'January 7, 2018' '1.0.0' '4.0.3 and up']

# %%
c = 0
for i in fd1:
    if(i[1]== "ART_AND_DESIGN" and i[2] > 4.5):
        c += 1
        print(i[0])
print(c)
# Out:
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Kids Paint Free - Drawing Fun
# Mandala Coloring Book
# Photo Designer - Write your name with shapes
# ibis Paint X
# Superheroes Wallpapers | 4K Backgrounds
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# I Creative Idea
# UNICORN - Color By Number & Pixel Art Coloring
# PIP Camera - PIP Collage Maker
# Canva: Poster, banner, card maker & graphic design
# Install images with music to make video without Net - 2018
# Cardi B Wallpaper
# X Launcher: With OS11 Style Theme & Control Center
# X Launcher Pro: PhoneX Theme, OS11 Control Center
# X Launcher Pro - IOS Style Theme & Control Center
# X Launcher Prime: With OS Style Theme & No Ads
# AJ Styles HD Wallpapers
# Fantasy theme dark bw black building
# Spring flowers theme couleurs d t space
# 22

# %%
c = 0
for i in fd1:
    if(i[1] == "FAMILY" and i[2] > 4.5 and i[6] == "Free"):
       c +=1
print(c)
# Out:
# 314

# %% [markdown]
# ## 2.Using Conditions

# %%
fd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
fd1=fd[fd["Category"] == "ART_AND_DESIGN" ]
fd1 = fd1[fd1["Rating"] > 4.7]
fd1 = fd1[fd1["Type"] == "Free"]

# %%
fd1.sort_values(by = "Rating" ,ascending = False)
# Out:
#                                           App        Category  Rating Reviews  \
# 8888  Spring flowers theme couleurs d t space  ART_AND_DESIGN     5.0       1
# 25                 Harley Quinn wallpapers HD  ART_AND_DESIGN     4.8     192
# 3982                        Cardi B Wallpaper  ART_AND_DESIGN     4.8     253
# 5254                  AJ Styles HD Wallpapers  ART_AND_DESIGN     4.8      48
# 6930     Fantasy theme dark bw black building  ART_AND_DESIGN     4.8      41
#
#       Size Installs  Type Price Content Rating        Genres  \
# 8888  2.9M     100+  Free     0       Everyone  Art & Design
# 25    6.0M  10,000+  Free     0       Everyone  Art & Design
# 3982  3.7M  50,000+  Free     0       Everyone  Art & Design
# 5254   25M   5,000+  Free     0       Everyone  Art & Design
# 6930  1.9M   5,000+  Free     0       Everyone  Art & Design
#
#           Last Updated Current Ver Android Ver
# 8888    April 18, 2018       1.0.2  4.0 and up
# ...

# %%
fd1=fd[fd["Category"] == "FAMILY" ]
fd1 = fd1[fd1["Rating"] > 4.7]
fd1 = fd1[fd1["Type"] == "Free"]

# %%
fd1.shape
# Out:
# (117, 13)

# %%
fd1=fd[fd["Category"] == "FAMILY" ]
fd1 = fd1[fd1["Rating"] > 4.7]
fd1 = fd1[fd1["Type"] == "Free"]

# %%
fd["Category"].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
fd1=fd[fd["Category"] == "WEATHER" ]
fd1 = fd1[fd1["Rating"] > 4.7]
fd1 = fd1[fd1["Type"] == "Free"]

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
fd1=fd[fd["Category"] == "BEAUTY" ]
fd1 = fd1[fd1["Content Rating"] == "Teen" ]
fd1 = fd1[fd1["Type"] == "Free"]

# %%
fd1
# Out:
#                                                  App Category  Rating Reviews  \
# 112    Selfie Camera Photo Editor & Filter & Sticker   BEAUTY     4.1     187
# 126                     Skin Care and Natural Beauty   BEAUTY     NaN     654
# 10289                                   Female Daily   BEAUTY     3.9    4354
#
#        Size  Installs  Type Price Content Rating  Genres    Last Updated  \
# 112     30M   50,000+  Free     0           Teen  Beauty   July 24, 2018
# 126    7.4M  100,000+  Free     0           Teen  Beauty   July 17, 2018
# 10289   42M  100,000+  Free     0           Teen  Beauty  August 6, 2018
#
#       Current Ver   Android Ver
# 112         3.0.1  4.0.3 and up
# 126          1.15    4.1 and up
# 10289       2.5.1  4.0.3 and up

# %%
fd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
fd.dropna(inplace = True)

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
fd.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Groupby Function

# %%
fd .head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
fd1 = fd.groupby(by = "Category").count()["Type"]

# %%
fd1
# Out:
# Category
# ART_AND_DESIGN           61
# AUTO_AND_VEHICLES        73
# BEAUTY                   42
# BOOKS_AND_REFERENCE     178
# BUSINESS                303
# COMICS                   58
# COMMUNICATION           328
# DATING                  195
# EDUCATION               155
# ENTERTAINMENT           149
# EVENTS                   45
# FAMILY                 1746
# FINANCE                 323
# FOOD_AND_DRINK          109
# GAME                   1097
# HEALTH_AND_FITNESS      297
# HOUSE_AND_HOME           76
# LIBRARIES_AND_DEMO       64
# LIFESTYLE               314
# MAPS_AND_NAVIGATION     124
# MEDICAL                 350
# NEWS_AND_MAGAZINES      233
# PARENTING                50
# PERSONALIZATION         312
# PHOTOGRAPHY             317
# PRODUCTIVITY            351
# SHOPPING                238
# SOCIAL                  259
# SPORTS                  319
# TOOLS                   733
# TRAVEL_AND_LOCAL        226
# VIDEO_PLAYERS           160
# ...

# %%
fd1 = fd.groupby('Content Rating').count()["Type"]

# %%
pd.DataFrame(fd1).reset_index()
# Out:
#     Content Rating  Type
# 0  Adults only 18+     3
# 1         Everyone  7414
# 2     Everyone 10+   397
# 3       Mature 17+   461
# 4             Teen  1084
# 5          Unrated     1
